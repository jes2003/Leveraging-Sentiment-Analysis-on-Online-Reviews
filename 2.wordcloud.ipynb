Unquestionable Unassailed Undisputed Unchallenged Unattackable Unexceptionable Unquestioned Unconquered Unvanquished Unblemished 
Unspotted Unsullied Unstinted Unmixed Unadulterated Unaltered Unmodified Unalloyed Uninfected Uncontaminated Unpolluted Unimpaired 
Unharmed Unchanged Unvarying Unwavering Unshaken Undamaged Unimpeachable Unflawed Unerring Untouched Unspoiled Untroubled Unaffected 
Unhurt Unsullied Unstained Unmarked Unbroken Unrivaled Unequalled Unmatched Unsurpassed Peerless Matchless Incomparable Beyond 
compare Without equal Unexampled Unprecedented Unrivaled Unique Singular Distinctive Unusual Rare Exceptional Extraordinary Uncommon 
Peculiar Odd Strange Eccentric Quirky Outlandish Bizarre Atypical Anomalous Abnormal Irregular Different Divergent Unusual Unexpected 
Unanticipated Surprising Startling Astonishing Amazing Staggering Astounding Miraculous Incredible Phenomenal Unbelievable Bewildering 
Breathtaking Awe-inspiring Sublime Wondrous Marvelous Prodigious Formidable Majestic Grand Noble Elegant Exalted Stately Regal Royal 
Imperial Kingly Sovereign Supreme Grandiose Monumental Palatial Lavish Sumptuous Opulent Luxurious Splendid Gorgeous Beautiful Elegant 
Graceful Refined Polished Charming
"""

# Create a WordCloud object
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(cleanliness_words)

# Display the word cloud using matplotlib
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
import wordcloud
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# List of words related to staff
staff_words = """
staff workforce manpower personnel pool crew employee worker help labor force team force company squad employee support labor band 
gang party helper rank_and_file proletariat outfit hireling Employee Worker Team Personnel Crew Staffing Colleague Co-worker 
Teammate Worker_bee Laborer Office_mate Jobholder Accommodation worker colleague laborer retainer jobholder associate 
hireling assistant subordinate hand underling coworker workman flunkey flunky flunkies cog yes-man wage_earner jobber 
hack wage_slave toiler workingman gandy_dancer workingwoman wage_worker drudge grub workingwoman temporary temp navvy 
nine-to-fiver ant kids ardent seniors singular family time admins equipment beds scepter serve school servers professor 
customer rod prof roster professors verge body space service crozier symbol devs guards support crosier doctor volunteer 
music cast weapon mods ply pit residents nurse distaff cater shield fax artist crook supply coaching facilities man 
rapier friends magic force drivers provide officer pikestaff tip_staff principle hospital hatchet parents axe lead quarterstaff 
guests general club cane bartenders kitchen special police funding hours developer truncheon contractors patrons budget 
ownership veterans agencies interns trainers hired room void tome driver writers help polearm working told great system server 
asked reporters briefing producers run worked deputy money administration teams studio chief pentagon officials leadership talent 
moonstone maintenance moderators advisors development according training army secretary restaurant actors tech spell associate local 
advised command informed services private provided ministry instructors assigned agency post military addition met defense meanwhile 
said director executive regularly pole affairs desk directors vice instructed positions noted interviewed commanders official served 
recently contacted workload principals work cadre sergeants adding bartender waitstaff requested complained also acting assistance 
spokesman head additional assignments jobs adviser paid
"""

# Create a WordCloud object
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(staff_words)

# Display the word cloud using matplotlib
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
import pandas as pd
import numpy as np

room_words = ["Room", "Bedroom", "Living-room", "Dining-room", "Kitchen", "Bathroom", "Hallway", "Closet", "Entryway", "Foyer", "Den", "Study",
              "Office", "Lounge", "Studio", "Loft", "Attic", "Basement", "Nursery", "Playroom", "Guest-room", "Powder-room", "Family-room", 
              "Recreation-room", "Solarium", "Sunroom", "Mudroom", "Pantry", "Walk-in-closet", "Coat-closet", "Linen-closet", "Utility-room",
              "Laundry-room", "Game-room", "Exercise-room", "Gym", "Theater-room", "Home-office", "Library", "Bookshelf", "Bookcase", "Shelving", 
              "Chair", "Sofa", "Couch", "Table", "Desk", "Bed", "Mattress", "Pillow", "Blanket", "Duvet", "Quilt", "Curtain", "Drapes", "Blinds",
              "Rug", "Carpet", "Flooring", "Tile", "Wallpaper", "Paint", "Ceiling", "Fan", "Light", "Lamp", "Chandelier", "Sconce", "Mirror", "Clock",
              "Artwork", "Painting", "Sculpture", "Decor", "Plant", "Vase", "Flower", "Window", "Door", "Knob", "Hinge", "Lock", "Key", "Window-seat",
              "Bench", "Ottoman", "Pouf", "Stool", "Chair-rail", "Wainscoting", "Crown-molding", "Baseboard", "Fireplace", "Mantel", "Hearth",
              "Chimney", "Radiator", "Air-conditioning", "Heater", "Ventilation", "Bunk-bed", "Canopy", "Murphy-bed", "Trundle-bed", "Nightstand",
              "Dresser", "Wardrobe", "Armoire", "Vanity", "Chest-of-drawers", "Chest", "Armchair", "Recliner", "Ottoman", "Loveseat", "Sectional",
              "Coffee-table", "End-table", "Dining-table", "Sideboard", "Buffet", "China-cabinet", "Barstool", "Counter", "Breakfast-nook",
              "Highchair", "Booster-seat", "Bar-cart", "Dishware", "Cutlery", "Utensils", "Glassware", "Dinnerware", "Serving-tray", "Placemat",
              "Tablecloth", "Napkin", "Dishwasher", "Refrigerator", "Freezer", "Stove", "Oven", "Microwave", "Sink", "Faucet", "Backsplash",
              "Countertop", "Cupboard", "Cabinet", "Spice-rack", "Trash-can", "Recycling-bin", "Compost-bin", "Towel-rack", "Shower", "Bathtub",
              "Vanity-mirror", "Medicine-cabinet", "Towel-hook", "Toilet", "Bidet", "Toilet-paper-holder", "Toilet-brush", "Soap-dispenser", 
              "Shower-curtain", "Towel-bar", "Bath-mat", "Toothbrush-holder", "Shampoo", "Conditioner", "Soap", "Lotion", "Candle", "Incense",
              "Potpourri", "Air-freshener", "Humidifier", "Dehumidifier", "Window-treatment", "Venetian-blinds", "Roman-shades", "Valance", "Shutter",
              "Floor-lamp", "Task-lamp", "Pendant-light", "Track-lighting", "Recessed-lighting", "Skylight", "Floor-cushion", "Bean-bag-chair", 
              "Wall-art", "Tapestry", "Poster", "Wall-clock", "Wall-shelf", "Wall-hook", "Wall-mirror", "Wall-sconce", "Wall-mural"]

room_words_lower = [word.lower() for word in room_words]

word_dictionary = {word: True for word in room_words_lower}

# Function to check if any word in the review is present in the dictionary
def check_review(review):
    if pd.notna(review):
        words_in_review = review.lower().split()
        for word in words_in_review:
            if word in word_dictionary:
                return True
        return False

# Apply the function to the 'review_clean' column
data['contains'] = data['review_clean'].apply(check_review)

data['room'] = data.apply(lambda row: row['review_clean'] if row['contains'] else '', axis=1)

print(data['room'])
# Out:
# 0        pleasant min walk along sea front water bus re...
# 1
# 2        good hotel lower rating get room roof full noi...
# 3        stay four night october hotel staff welcome fr...
# 4        love stay island lido need take water venice g...
#                                ...
# 20507
# 20508
# 20509    stay sit night attend jet's game next day get ...
# 20510
# 20511
# Name: room, Length: 20512, dtype: object

# %%
data['contains'].value_counts()
# Out:
# contains
# True     12859
# False     7621
# Name: count, dtype: int64

# %%
import pandas as pd
import numpy as np

stay_words = ["Stay", "Accommodation", "Lodging", "Residence", "Dwelling", "Housing", "Shelter", "Hotel", "Motel", "Inn", "Hostel", 
                       "Guesthouse", "Bed and Breakfast", "Vacation Rental", "Cottage", "Cabin", "Suite", "Staying", "Live-in", "Domicile", "Digs", 
                       "Rooming House", "Hideaway", "Inhabitation", "Perch", "Tenant", "Lair", "Host's Quarters", "Lodge", "Retirement Home", 
                       "Boutique Hotel", "Historic Inn", "Extended Stay", "Cozy", "Comfortable", "Tranquil", "Quaint", "Luxurious", "Elegant", "Rustic", 
                       "Chic", "Secluded", "Urban", "Rural", "Modern", "Veranda", "Yard", "Garden", "Swimming Pool", "Fitness Center", "Spa", 
                       "Sauna", "Hot Tub", "Wi-Fi", "High-Speed Internet", "Cable TV", "Air Conditioning", "Heating", "Fireplace", "Security", "Safety", 
                       "Keycard Access", "Room Service", "Housekeeping", "Laundry", "Ironing", "Mini Bar", "Tea and Coffee Facilities", "Toiletries", 
                       "Hairdryer", "Bathrobe", "Slippers", "Towel Service", "Complimentary Breakfast", "Free Parking", "Shuttle Service", "Airport Transfer", 
                       "Ceiling", "Lighting", "Lamp", "Chandelier", "Sconces", "Floor Lamp", "Table Lamp", "Desk", "Chair", "Sofa", "Couch", 
                       "Armchair", "Dining Table", "Coffee Table", "Side Table", "Nightstand", "Weather", "Rain", "Sunshine", "Snow", "Wind", "Temperature", "Climate", "Seasons", "Spring", "Summer", "Autumn", "Winter", 
                       "Furniture", "Furnishings", "Cushions", "Throws", "Linen", "Dining", "Utensils", "Cutlery"]

stay_words_lower = [word.lower() for word in stay_words]

word_dictionary = {word: True for word in stay_words_lower}

# Function to check if any word in the review is present in the dictionary
def check_review(review):
    if pd.notna(review):
        words_in_review = review.lower().split()
        for word in words_in_review:
            if word in word_dictionary:
                return True
        return False

# Apply the function to the 'review_clean' column
data['contains_stay'] = data['review_clean'].apply(check_review)

data['stay'] = data.apply(lambda row: row['review_clean'] if row['contains_stay'] else '', axis=1)

print(data['stay'])
# Out:
# 0        pleasant min walk along sea front water bus re...
# 1        really lovely hotel stay top floor surprise ja...
# 2        good hotel lower rating get room roof full noi...
# 3        stay four night october hotel staff welcome fr...
# 4        love stay island lido need take water venice g...
#                                ...
# 20507    great time great location friendly staff hotel...
# 20508
# 20509    stay sit night attend jet's game next day get ...
# 20510                                           great stay
# 20511    get see granddaughter graduate college go new ...
# Name: stay, Length: 20512, dtype: object

# %%
data['contains_stay'].value_counts()
# Out:
# contains_stay
# True     14482
# False     5998
# Name: count, dtype: int64

# %%
import pandas as pd
import numpy as np

clean_words = ["Clean", "Neat", "Tidy", "Spotless", "Immaculate", "Sanitary", "Hygienic", "Fresh", "Pure", "Clear", "Unsoiled", "Unblemished", 
                    "Pristine", "Sparkling", "Glistening", "Polished", "Shiny", "Lustrous", "Gleaming", "Bright", "Crisp", "Clear-cut", "Squeaky-clean", 
                    "Washed", "Scrubbed", "Swept", "Mopped", "Dust-free", "Sterile", "Disinfected", "Antiseptic", "Aseptic", "Hygienized", "Purified", 
                    "Decontaminated", "Deodorized", "Odor-free", "Fragrant", "Aromatic", "Perfumed", "Deodorant", "Germ-free", "Bacteria-free", 
                    "Virus-free", "Fungus-free", "Antimicrobial", "Disinfestation", "Pest-free", "Pest-control", "Bug-free", "Insect-free", "Rodent-free", 
                    "Vermin-free", "Pest-resistant", "Weed-free", "Sanitization", "Sterilization", "Disinfection", "Cleaning", "Purging", "Detoxification", 
                    "Restoration", "Renovation", "Revitalization", "Renewal", "Refurbishment", "Improvement", "Upgrade", "Enhancement", "Rejuvenation", 
                    "Freshening", "Decontamination", "Laundered", "Dry-cleaned", "Pressed", "Ironed", "Folded", "Organized", "Arranged", "Systematized", 
                    "Orderly", "Systematic", "Methodical", "Regulated", "Controlled", "Regular", "Consistent", "Planned", "Disciplined", "Coordinated", 
                    "Arranged", "Sorted", "Categorized", "Classified", "Filed", "Cataloged", "Indexed", "Alphabetized", "Systematized", "Ordered", 
                    "Neatened", "Straightened", "Aligned", "Stacked", "Organized", "Systemized", "Symmetrical", "Uncluttered", "Simplified", "Streamlined", 
                    "Minimized", "Efficient", "Effective", "Economical", "Frugal", "Spick-and-span", "Shipshape", "Prim", "Proper", "Decent", "Respectable", 
                    "Dapper", "Impeccable", "Faultless", "Flawless", "Perfect", "Exemplary", "Exquisite", "Ideal", "Unspoiled", "Untarnished", "Unadulterated", 
                    "Uncontaminated", "Untouched", "Unpolluted", "Unimpaired", "Unharmed", "Unstained", "Unmarred", "Unspoiled", "Untouched", "Unmarked", 
                    "Unblighted", "Unblemished", "Unmixed", "Unalloyed", "Unfouled", "Unmodified", "Unscathed", "Unsoiled", "Uninjured", "Unhurt", 
                    "Unbroken", "Unflawed", "Unaffected", "Unimpeachable", "Unobjectionable", "Unassailable", "Irreproachable", "Unquestionable", 
                    "Unassailed", "Undisputed", "Unchallenged", "Unattackable", "Unexceptionable", "Unquestioned", "Unconquered", "Unblemished", 
                    "Unspotted", "Unsullied", "Unstinted", "Unmixed", "Unadulterated", "Unaltered", "Unmodified", "Unalloyed", "Uninfected", 
                    "Uncontaminated", "Unpolluted", "Unimpaired", "Unharmed", "Unchanged", "Unvarying", "Unwavering", "Unshaken", "Undamaged"]

clean_words_lower = [word.lower() for word in clean_words]

word_dictionary = {word: True for word in clean_words_lower}

# Function to check if any word in the review is present in the dictionary
def check_review(review):
    if pd.notna(review):
        words_in_review = review.lower().split()
        for word in words_in_review:
            if word in word_dictionary:
                return True
        return False

# Apply the function to the 'review_clean' column
data['contains_clean'] = data['review_clean'].apply(check_review)

data['clean'] = data.apply(lambda row: row['review_clean'] if row['contains_clean'] else '', axis=1)

print(data['clean'])
# Out:
# 0
# 1
# 2
# 3        stay four night october hotel staff welcome fr...
# 4        love stay island lido need take water venice g...
#                                ...
# 20507
# 20508
# 20509    stay sit night attend jet's game next day get ...
# 20510
# 20511    get see granddaughter graduate college go new ...
# Name: clean, Length: 20512, dtype: object

# %%
data['contains_clean'].value_counts()
# Out:
# contains_clean
# False    13517
# True      6963
# Name: count, dtype: int64

# %%
import pandas as pd
import numpy as np

staff_words = ["staff", "workforce", "manpower", "personnel", "pool", "crew", "employee", "worker", "help", "labor force", 
                   "team", "force", "company", "squad", "employee support", "labor", "band", "gang", "party", "helper", 
                   "rank_and_file", "proletariat", "outfit", "hireling", "Employee", "Worker", "Team", "Personnel", "Crew", 
                   "Staffing", "Colleague", "Co-worker", "Teammate", "Worker_bee", "Laborer", "Office_mate", "Jobholder", 
                   "Accommodation worker", "colleague", "laborer", "retainer", "jobholder", "associate", "hireling", 
                   "assistant", "subordinate", "hand", "underling", "coworker", "workman", "flunkey", "flunky", "flunkies", 
                   "cog", "yes-man", "wage_earner", "jobber", "hack", "wage_slave", "toiler", "workingman", "gandy_dancer", 
                   "workingwoman", "wage_worker", "drudge", "grub", "workingwoman", "temporary", "temp", "navvy", "nine-to-fiver", 
                   "ant", "kids", "ardent", "seniors", "singular", "family", "time", "admins", "equipment", "beds", "scepter", 
                   "serve", "school", "servers", "professor", "customer", "rod", "prof", "roster", "professors", "verge", "body", 
                   "space", "service", "crozier", "symbol", "devs", "guards", "support", "crosier", "doctor", "volunteer", "driver", "writers", 
                   "help", "polearm", "working", "told", "great", "system", "server", "asked", "reporters", "briefing", "producers", 
                   "run", "worked", "deputy", "money", "administration", "teams", "studio", "chief", "pentagon", "officials", "leadership", 
                   "talent", "moonstone", "maintenance", "moderators", "advisors", "development", "according", "training", "army",
                   "secretary", "restaurant", "actors", "tech", "spell", "associate", "local", "advised", "command", "informed",
                   "services", "private", "provided", "ministry", "instructors", "assigned", "agency", "post", "military", "addition", 
                   "met", "defense", "meanwhile", "said", "director", "executive", "regularly", "pole", "affairs", "desk", "directors", 
                   "vice", "instructed", "positions", 
                   "noted", "interviewed", "commanders", "official", "served", "recently", "contacted", "workload", "principals", "work", 
                   "cadre", "sergeants", "adding", "bartender", "waitstaff", "requested", "complained", "also", "acting", "assistance", 
                   "spokesman", "head", "additional", "assignments", "jobs", "adviser", "paid"]

staff_words_lower = [word.lower() for word in staff_words]

word_dictionary = {word: True for word in staff_words_lower}

# Function to check if any word in the review is present in the dictionary
def check_review(review):
    if pd.notna(review):
        words_in_review = review.lower().split()
        for word in words_in_review:
            if word in word_dictionary:
                return True
        return False

# Apply the function to the 'review_clean' column
data['contains_staff'] = data['review_clean'].apply(check_review)

data['staff'] = data.apply(lambda row: row['review_clean'] if row['contains_staff'] else '', axis=1)

print(data['staff'])
# Out:
# 0        pleasant min walk along sea front water bus re...
# 1        really lovely hotel stay top floor surprise ja...
# 2
# 3        stay four night october hotel staff welcome fr...
# 4
#                                ...
# 20507    great time great location friendly staff hotel...
# 20508    great staff wonderful boyfriend become ill eve...
# 20509    stay sit night attend jet's game next day get ...
# 20510                                           great stay
# 20511    get see granddaughter graduate college go new ...
# Name: staff, Length: 20512, dtype: object

# %%
data['contains_staff'].value_counts()
# Out:
# contains_staff
# True     13985
# False     6495
# Name: count, dtype: int64

# %%
hotel=data[['name','reviews.text','reviews.rating','review_clean','room','stay','clean','staff']]

# %%
hotel
# Out:
#                                                     name  \
# 0                                     Hotel Russo Palace
# 1                                     Hotel Russo Palace
# 2                                     Hotel Russo Palace
# 3                                     Hotel Russo Palace
# 4                                     Hotel Russo Palace
# ...                                                  ...
# 20507  Holiday Inn Express Hotel and Suites Meadowlan...
# 20508  Holiday Inn Express Hotel and Suites Meadowlan...
# 20509  Holiday Inn Express Hotel and Suites Meadowlan...
# 20510  Holiday Inn Express Hotel and Suites Meadowlan...
# 20511  Holiday Inn Express Hotel and Suites Meadowlan...
#
#                                             reviews.text  reviews.rating  \
# 0      Pleasant 10 min walk along the sea front to th...             4.0
# 1      Really lovely hotel. Stayed on the very top fl...             5.0
# ...

# %%
hotel.to_csv('hotel_with_attributes.csv')

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("hotel_with_attributes.csv")
print("The dataset with extracted attributes\n")
df = df.loc[:, ~df.columns.str.contains('^Unnamed')]
df
# Out:
# The dataset with extracted attributes
#                                                     name  \
# 0                                     Hotel Russo Palace
# 1                                     Hotel Russo Palace
# 2                                     Hotel Russo Palace
# 3                                     Hotel Russo Palace
# 4                                     Hotel Russo Palace
# ...                                                  ...
# 20507  Holiday Inn Express Hotel and Suites Meadowlan...
# 20508  Holiday Inn Express Hotel and Suites Meadowlan...
# 20509  Holiday Inn Express Hotel and Suites Meadowlan...
# 20510  Holiday Inn Express Hotel and Suites Meadowlan...
# 20511  Holiday Inn Express Hotel and Suites Meadowlan...
#
#                                             reviews.text  reviews.rating  \
# 0      Pleasant 10 min walk along the sea front to th...             4.0
# 1      Really lovely hotel. Stayed on the very top fl...             5.0
# ...

# %%
df['reviews.rating'] = df['reviews.rating'].astype(float)  # Ensure the 'reviews.rating' column is of numeric type
filtered_df = df[df['reviews.rating'] <= 5]
filtered_df
# Out:
#                                                     name  \
# 0                                     Hotel Russo Palace
# 1                                     Hotel Russo Palace
# 2                                     Hotel Russo Palace
# 3                                     Hotel Russo Palace
# 4                                     Hotel Russo Palace
# ...                                                  ...
# 20507  Holiday Inn Express Hotel and Suites Meadowlan...
# 20508  Holiday Inn Express Hotel and Suites Meadowlan...
# 20509  Holiday Inn Express Hotel and Suites Meadowlan...
# 20510  Holiday Inn Express Hotel and Suites Meadowlan...
# 20511  Holiday Inn Express Hotel and Suites Meadowlan...
#
#                                             reviews.text  reviews.rating  \
# 0      Pleasant 10 min walk along the sea front to th...             4.0
# 1      Really lovely hotel. Stayed on the very top fl...             5.0
# ...

# %%
df['reviews.rating'] = df['reviews.rating'].astype(int)  # Ensure the 'reviews.rating' column is of numeric type
df['reviews.rating'] = df['reviews.rating'].clip(upper=5.0)  # Clip values to be less than or equal to 5.0
filtered_df = df[df['reviews.rating'] <= 5]
filtered_df
# Out:
#                                                     name  \
# 0                                     Hotel Russo Palace
# 1                                     Hotel Russo Palace
# 2                                     Hotel Russo Palace
# 3                                     Hotel Russo Palace
# 4                                     Hotel Russo Palace
# ...                                                  ...
# 20507  Holiday Inn Express Hotel and Suites Meadowlan...
# 20508  Holiday Inn Express Hotel and Suites Meadowlan...
# 20509  Holiday Inn Express Hotel and Suites Meadowlan...
# 20510  Holiday Inn Express Hotel and Suites Meadowlan...
# 20511  Holiday Inn Express Hotel and Suites Meadowlan...
#
#                                             reviews.text  reviews.rating  \
# 0      Pleasant 10 min walk along the sea front to th...               4
# 1      Really lovely hotel. Stayed on the very top fl...               5
# ...

# %%
df['sentiment_label'] = df['reviews.rating'].apply(lambda x: 1 if x == 5 else (0 if x in [3, 4] else -1))
print(df['sentiment_label'])
# Out:
# 0        0
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 20507    1
# 20508    1
# 20509    0
# 20510    1
# 20511    1
# Name: sentiment_label, Length: 20512, dtype: int64

# %%
df.to_csv('hotel_with_sentiments.csv')
